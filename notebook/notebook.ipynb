# %%
from config import PATHS

print(PATHS["raw"])
# Out:
# /mnt/d/IITJ/Course/sem7/BigData/Project/raw

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("RecommenderGraph") \
    .master("local[*]") \
    .config("spark.driver.memory", "3g") \
    .config("spark.executor.memory", "3g") \
    .config("spark.hadoop.fs.defaultFS", "file:///") \
    .getOrCreate()
# Out:
# 26/03/31 06:46:44 WARN Utils: Your hostname, devmachine resolves to a loopback address: 127.0.1.1; using 172.31.239.142 instead (on interface eth0)
# 26/03/31 06:46:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/31 06:46:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.json("/mnt/d/IITJ/Course/sem7/BigData/Project/raw/Movies_and_TV_5.json")
df.show(5)
# Out:
# +----------+-----+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------------+--------------+--------+----+
# |      asin|image|overall|          reviewText| reviewTime|    reviewerID|        reviewerName|               style|             summary|unixReviewTime|verified|vote|
# +----------+-----+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------------+--------------+--------+----+
# |0005089549| null|    5.0|So sorry I didn't...| 11 9, 2012|A2M1CU2IRZG0K9|               Terri|{ VHS Tape, null,...|            Amazing!|    1352419200|    true|null|
# |0005089549| null|    5.0|Believe me when I...|12 30, 2011| AFTUJYISOFHY6|Melissa D. Abercr...|{ VHS Tape, null,...|Great Gospel VHS ...|    1325203200|    true|null|
# |000503860X| null|    5.0|I have seen X liv...|04 21, 2005|A3JVF9Y53BEOGC|    Anthony Thompson|  { DVD, null, null}|A great document ...|    1114041600|    true|  11|
# |000503860X| null|    5.0|I was so excited ...| 04 6, 2005|A12VPEOEZS1KTC|            JadeRain|  { DVD, null, null}|     YES!!  X LIVE!!|    1112745600|    true|   5|
# |000503860X| null|    5.0|X is one of the b...| 12 3, 2010| ATLZNVLYKP9AZ|           T. Fisher|  { DVD, null, null}| X have still got it|    1291334400|    true|   5|
# +----------+-----+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------------+--------------+--------+----+
# only showing top 5 rows

# %%
print(PATHS["raw"])
# Out:
# /mnt/d/IITJ/Course/sem7/BigData/Project/raw

# %%
spark.stop()

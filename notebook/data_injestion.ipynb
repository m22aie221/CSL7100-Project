# %%
import sys
sys.path.append("/home/rajesh/CSL7100-Project/code")  # adjust path if needed

from etl import run_etl

# %%
from config import print_config
from etl import run_etl

print_config()
run_etl()
# Out:
# 🔧 CONFIGURATION
# PROJECT_ROOT: /mnt/d/IITJ/Course/sem7/BigData/Project
# USE_HDFS: False
# BASE_PATH: file:///mnt/d/IITJ/Course/sem7/BigData/Project
# PATHS:
#   raw: file:///mnt/d/IITJ/Course/sem7/BigData/Project/raw
#   parquet: file:///mnt/d/IITJ/Course/sem7/BigData/Project/parquet
#   hdfs: file:///mnt/d/IITJ/Course/sem7/BigData/Project/hdfs
#   spark_temp: file:///mnt/d/IITJ/Course/sem7/BigData/Project/spark-temp
# 💻 Running in LOCAL mode
# 26/04/01 18:22:16 WARN Utils: Your hostname, devmachine resolves to a loopback address: 127.0.1.1; using 172.31.239.142 instead (on interface eth0)
# 26/04/01 18:22:16 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/01 18:22:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 📥 Loading data from: file:///mnt/d/IITJ/Course/sem7/BigData/Project/raw
# ✅ Removed rows with null user/item/rating
# 💾 Saving to: file:///mnt/d/IITJ/Course/sem7/BigData/Project/parquet
# ✅ ETL Completed

# %%
#Data Validation (Quick sanity check)

# %%
from pyspark.sql import SparkSession
from config import PATHS

spark = SparkSession.builder.getOrCreate()

df = spark.read.parquet(PATHS["parquet"])

df.show(5)
df.printSchema()
print("Total records:", df.count())
# Out:
# +--------------+----------+-------+--------------+
# |    reviewerID|      asin|overall|unixReviewTime|
# +--------------+----------+-------+--------------+
# |A1UNFTXYKPDGTM|B00J1Z401K|    4.0|    1426723200|
# | ATAM677G1BF7B|B00J1Z401K|    4.0|    1425945600|
# |A15RE5GEHGP8DH|B00J1Z401K|    5.0|    1416182400|
# | AFBG9UEBQ4Q6D|B00J1Z401K|    4.0|    1414886400|
# |A2EIFPCF164MYK|B00J1Z401K|    1.0|    1412121600|
# +--------------+----------+-------+--------------+
# only showing top 5 rows
#
# root
#  |-- reviewerID: string (nullable = true)
#  |-- asin: string (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- unixReviewTime: long (nullable = true)
#
# Total records: 3410019

# %%
#Basic Statistics
df.describe().show()
# Out:
# [Stage 5:===================================================>       (7 + 1) / 8]
# +-------+--------------------+--------------------+------------------+--------------------+
# |summary|          reviewerID|                asin|           overall|      unixReviewTime|
# +-------+--------------------+--------------------+------------------+--------------------+
# |  count|             3410019|             3410019|           3410019|             3410019|
# |   mean|                null| 5.509913886106568E9| 4.221320174462371|1.3845512740540156E9|
# | stddev|                null|2.0372923441616936E9|1.1664558754885506|1.1585143827730224E8|
# |    min|A0009988MRFQ3TROTQPI|          0000143588|               1.0|           881020800|
# |    max|       AZZZMSZI9LKE6|          B01HJ1INB0|               5.0|          1538352000|
# +-------+--------------------+--------------------+------------------+--------------------+

# %%
print("Users:", df.select("reviewerID").distinct().count())
print("Items:", df.select("asin").distinct().count())
# Out:
# Users: 297529
# [Stage 14:=====================>                                    (3 + 5) / 8]
# Items: 60175

# %%
from filter_5core import run_5core

run_5core()
# Out:
# 💻 Running in LOCAL mode
# 📥 Loading data from: file:///mnt/d/IITJ/Course/sem7/BigData/Project/parquet
# Initial records: 680776
#
# 🔁 Iteration 1
# 🔁 Iteration 2
# ✅ Converged
# 💾 Saving filtered data to: file:///mnt/d/IITJ/Course/sem7/BigData/Project/parquet/5core
# ✅ 5-core filtering completed

# %%
from encode_ids import run_encoding

run_encoding()
# Out:
# 💻 Running in LOCAL mode
# 📥 Loading: file:///mnt/d/IITJ/Course/sem7/BigData/Project/parquet/5core
# 💾 Saving: file:///mnt/d/IITJ/Course/sem7/BigData/Project/parquet/encoded
# ✅ ID Encoding Completed

# %%
from etl import create_spark_session

spark = create_spark_session()



df = spark.read.parquet(PATHS["parquet"] + "/encoded")
df.show(5)
df.printSchema()
# Out:
# 💻 Running in LOCAL mode
# 💻 Running in LOCAL mode
# +-------+-------+-------+--------------+
# |user_id|item_id|overall|unixReviewTime|
# +-------+-------+-------+--------------+
# |  16266|      0|    5.0|    1128556800|
# |  18958|      0|    5.0|    1080259200|
# |  18933|      0|    5.0|    1255219200|
# |  14779|      0|    4.0|    1392249600|
# |  18638|      0|    4.0|    1071878400|
# +-------+-------+-------+--------------+
# only showing top 5 rows
#
# root
#  |-- user_id: long (nullable = true)
#  |-- item_id: long (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- unixReviewTime: long (nullable = true)

# %%
from graph_builder import build_graph

df = spark.read.parquet(PATHS["parquet"] + "/encoded")

vertices, edges = build_graph(spark, df)

vertices.show(5)
edges.show(5)
# Out:
# Max user_id: 20224
# +-----+----+
# |   id|type|
# +-----+----+
# | 7747|user|
# | 2509|user|
# |17703|user|
# |14846|user|
# | 4894|user|
# +-----+----+
# only showing top 5 rows
#
# +-----+-----+------+
# |  src|  dst|weight|
# +-----+-----+------+
# |16266|20225|   5.0|
# |18958|20225|   5.0|
# |18933|20225|   5.0|
# |14779|20225|   4.0|
# |18638|20225|   4.0|
# +-----+-----+------+
# only showing top 5 rows

# %%
from graph_builder import run_graph_builder
run_graph_builder()
# Out:
# 💻 Running in LOCAL mode
# 📥 Loading: file:///mnt/d/IITJ/Course/sem7/BigData/Project/parquet/encoded
# Max user_id: 20224
# 💾 Saving vertices...
# 💾 Saving edges...
# ✅ Graph Construction Completed

# %%
from etl import create_spark_session

spark = create_spark_session()

vertices = spark.read.parquet(PATHS["parquet"] + "/graph/vertices")
edges = spark.read.parquet(PATHS["parquet"] + "/graph/edges")
# Out:
# 💻 Running in LOCAL mode

# %%
# 1. User exists
vertices.filter(col("id") == source_user).show()

# 2. User is type=user
vertices.filter((col("id") == source_user) & (col("type") == "user")).show()

# 3. User has edges
edges.filter(col("src") == source_user).show()
# Out:
# +-----+----+
# |   id|type|
# +-----+----+
# |16266|user|
# +-----+----+
#
# +-----+----+
# |   id|type|
# +-----+----+
# |16266|user|
# +-----+----+
#
# +-----+-----+------+
# |  src|  dst|weight|
# +-----+-----+------+
# |16266|20225|   5.0|
# |16266|20227|   1.0|
# |16266|20467|   4.0|
# |16266|20718|   5.0|
# |16266|22149|   3.0|
# |16266|22498|   3.0|
# |16266|23124|   5.0|
# |16266|23946|   4.0|
# |16266|23975|   5.0|
# |16266|25534|   5.0|
# |16266|26177|   4.0|
# |16266|26442|   3.0|
# |16266|26647|   4.0|
# |16266|27756|   4.0|
# |16266|27868|   4.0|
# |16266|27936|   4.0|
# |16266|27976|   3.0|
# |16266|28386|   5.0|
# |16266|28705|   5.0|
# |16266|28833|   4.0|
# +-----+-----+------+
# only showing top 20 rows

# %%
source_user = edges.select("src").distinct().limit(1).collect()[0][0]

# %%
ranks = personalized_pagerank(spark, vertices, edges, source_user)
ranks.orderBy("rank", ascending=False).show(10)
# Out:
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# [Stage 11:>                                                         (0 + 1) / 1]
# +---+----+
# | id|rank|
# +---+----+
# +---+----+

# %%
from ppr import personalized_pagerank
from pyspark.sql import SparkSession
from config import PATHS

spark = SparkSession.builder.getOrCreate()

# Load graph
vertices = spark.read.parquet(PATHS["parquet"] + "/graph/vertices")
edges = spark.read.parquet(PATHS["parquet"] + "/graph/edges")

# Choose a user
source_user = 10

ranks = personalized_pagerank(
    spark,
    vertices,
    edges,
    source_id=source_user,
    alpha=0.15,
    max_iter=10
)

ranks.orderBy("rank", ascending=False).show(10)
# Out:
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# [Stage 5:>                                                          (0 + 1) / 1]
# +---+----+
# | id|rank|
# +---+----+
# +---+----+

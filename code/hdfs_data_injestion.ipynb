# %%
import sys
sys.path.append("/home/rajesh/CSL7100-Project/code")  # adjust path if needed

from etl import run_etl

# %%
from pyspark.sql import SparkSession
from config import PATHS

# %%
from config import print_config
from etl import run_etl

print_config()
run_etl()
# Out:
# 🔧 CONFIGURATION
# PROJECT_ROOT: /mnt/d/IITJ/Course/sem7/BigData/Project
# USE_HDFS: True
# BASE_PATH: hdfs://localhost:9000/project
# PATHS:
#   raw: hdfs://localhost:9000/project/raw
#   parquet: hdfs://localhost:9000/project/parquet
#   graph: hdfs://localhost:9000/project/parquet/graph
#   checkpoint: hdfs://localhost:9000/project/checkpoints
#   spark_temp: hdfs://localhost:9000/project/spark-temp
# 🚀 Running in HDFS mode
# 26/04/14 22:26:03 WARN Utils: Your hostname, devmachine resolves to a loopback address: 127.0.1.1; using 172.31.239.142 instead (on interface eth0)
# 26/04/14 22:26:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/14 22:26:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/14 22:26:10 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 📥 Loading data from: hdfs://localhost:9000/project/raw
# ✅ Removed nulls
# 💾 Saving to: hdfs://localhost:9000/project/parquet
# ✅ ETL Completed

# %%
#Data Validation (Quick sanity check)

# %%
from pyspark.sql import SparkSession
from config import PATHS
from etl import create_spark_session

spark = create_spark_session()

#df = spark.read.parquet(PATHS["parquet"])
df = spark.read.parquet(PATHS["parquet"])


df.show(5)
df.printSchema()
print("Total records:", df.count())
spark.stop()
# Out:
# 🚀 Running in HDFS mode
# 26/04/14 22:30:34 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# +--------------+----------+-------+--------------+
# |    reviewerID|      asin|overall|unixReviewTime|
# +--------------+----------+-------+--------------+
# |A16XRPF40679KG|6301767918|    5.0|    1345680000|
# |A2BDZAU0Y4J6NB|0790736527|    3.0|    1221436800|
# |A1IYGRATK4W76O|0790736063|    5.0|    1082937600|
# |A3TZY1YBF8TEI4|6300213986|    5.0|    1460937600|
# |  ABS2A1OWX5Q8|6300216632|    5.0|    1408406400|
# +--------------+----------+-------+--------------+
# only showing top 5 rows
#
# root
#  |-- reviewerID: string (nullable = true)
#  |-- asin: string (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- unixReviewTime: long (nullable = true)
# Total records: 170794

# %%
#Basic Statistics
df.describe().show()
# Out:
# [Stage 8:====================================>                      (5 + 3) / 8]
# +-------+--------------------+-------------------+-----------------+--------------------+
# |summary|          reviewerID|               asin|          overall|      unixReviewTime|
# +-------+--------------------+-------------------+-----------------+--------------------+
# |  count|              170418|             170418|           170418|              170418|
# |   mean|                null|5.526572447850184E9|4.220933234752198|1.3848529613914022E9|
# | stddev|                null|2.023860512329403E9|1.168561745544952|1.1556405983621776E8|
# |    min|A0045750NMY09KVSTE01|         0001526863|              1.0|           895449600|
# |    max|       AZZZMSZI9LKE6|         B01HIUL6WU|              5.0|          1537574400|
# +-------+--------------------+-------------------+-----------------+--------------------+

# %%
import importlib
importlib.reload(importlib)
from filter_5core import run_5core
run_5core()
# Out:
# 🚀 Running in HDFS mode
# 26/04/14 22:53:26 WARN Utils: Your hostname, devmachine resolves to a loopback address: 127.0.1.1; using 172.31.239.142 instead (on interface eth0)
# 26/04/14 22:53:26 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/14 22:53:29 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/14 22:53:32 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 📥 Loading data from: hdfs://localhost:9000/project/parquet
# Initial records: 170794
#
# 🔁 Iteration 1
# 🔁 Iteration 2
# 🔁 Iteration 3
# 🔁 Iteration 4
# 🔁 Iteration 5
#
# 🔁 Iteration 6
# 🔁 Iteration 7
#
# 🔁 Iteration 8
#
# 🔁 Iteration 9
# 🔁 Iteration 10
# 💾 Saving filtered data to: hdfs://localhost:9000/project/parquet/5core
# ✅ 5-core filtering completed

# %%
import encode_ids
import importlib

importlib.reload(encode_ids)
# Out:
# <module 'encode_ids' from '/home/rajesh/CSL7100-Project/code/encode_ids.py'>

# %%
from encode_ids import run_encoding

run_encoding()
# Out:
# 🚀 Running in HDFS mode
# 26/04/14 22:58:15 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# ✅ Encoded saved
# ✅ ID Encoding Completed

# %%
from etl import create_spark_session

spark = create_spark_session()

df = spark.read.parquet(PATHS["parquet"] + "/encoded")

df.show(5)
df.printSchema()
spark.stop()
# Out:
# 🚀 Running in HDFS mode
# +-------+-------+-------+--------------+
# |user_id|item_id|overall|unixReviewTime|
# +-------+-------+-------+--------------+
# |      0|      0|    4.0|    1443225600|
# |      1|      0|    5.0|    1442361600|
# |      2|      0|    5.0|    1466726400|
# |      3|      0|    5.0|    1480896000|
# |      3|      1|    4.0|    1455667200|
# +-------+-------+-------+--------------+
# only showing top 5 rows
#
# root
#  |-- user_id: long (nullable = true)
#  |-- item_id: long (nullable = true)
#  |-- overall: double (nullable = true)
#  |-- unixReviewTime: long (nullable = true)

# %%
import importlib
importlib.reload(graph_builder)
import graph_builder
from graph_builder import run_graph_builder
run_graph_builder()
# Out:
# 🚀 Running in HDFS mode
# 26/04/14 23:03:45 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 📥 Loading: hdfs://localhost:9000/project/parquet/encoded
# Max user_id: 266287973175
# Vertices: 37888
# Edges: 143078
# 💾 Saving vertices...:  37888
# 💾 Saving edges...:  143078
# ✅ Graph Construction Completed

# %%
from etl import create_spark_session
from pyspark.sql.functions import col
spark = create_spark_session()

vertices = spark.read.parquet(PATHS["parquet"] + "/graph/vertices")
edges = spark.read.parquet(PATHS["parquet"] + "/graph/edges")
# Out:
# 🚀 Running in HDFS mode
# 26/04/14 23:04:26 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# 1. User exists
source_user = 148   # example from your edges output
vertices.filter(col("id") == source_user).show()

# 2. User is type=user
vertices.filter((col("id") == source_user) & (col("type") == "user")).show()

# 3. User has edges
edges.filter(col("src") == source_user).show()

# Check if weights sum to 1 per user (important for PPR)
from pyspark.sql.functions import sum

edges.groupBy("src").agg(sum("weight")).show(5)
# Out:
# +---+----+
# | id|type|
# +---+----+
# |148|user|
# +---+----+
#
# +---+----+
# | id|type|
# +---+----+
# |148|user|
# +---+----+
# +---+------------+------+
# |src|         dst|weight|
# +---+------------+------+
# |148|266287973318|  0.25|
# |148|266287973720|  0.25|
# |148|266287973803|  0.25|
# |148|266287974933|  0.25|
# +---+------------+------+
# [Stage 9:>                                                          (0 + 6) / 6]
# +------------+------------------+
# |         src|       sum(weight)|
# +------------+------------------+
# |  8589934980|               1.0|
# | 42949673746|               1.0|
# |266287973230|               1.0|
# |266287973309|               1.0|
# |266287973394|0.9999999999999999|
# +------------+------------------+
# only showing top 5 rows

# %%
source_user = edges.select("src").distinct().limit(1).collect()[0][0]

# %%
from ppr import personalized_pagerank 
#ranks = personalized_pagerank(spark, vertices, edges, source_user)
#ranks.orderBy("rank", ascending=False).show(10)

# %%
from ppr import personalized_pagerank,personalized_pagerank_optimized
from pyspark.sql import SparkSession
from config import PATHS

spark = SparkSession.builder.getOrCreate()
spark.sparkContext.setCheckpointDir("/tmp/spark-checkpoints")
# Load graph
vertices = spark.read.parquet(PATHS["parquet"] + "/graph/vertices")
edges = spark.read.parquet(PATHS["parquet"] + "/graph/edges")

# Choose a user
source_user = 10
ranks, top_items = personalized_pagerank_optimized(
    spark,
    vertices,
    edges,
    source_id=source_user,
    alpha=0.15,
    max_iter=20,
    top_n=10
)

# Show results
top_items.show()

'''ranks = personalized_pagerank(
    spark,
    vertices,
    edges,
    source_id=source_user,
    alpha=0.15,
    max_iter=10
)'''

ranks.orderBy("rank", ascending=False).show(10)
# Out:
# 🚀 Starting Personalized PageRank
# 🔄 Making graph bidirectional
# 🎯 Source user: 10
#
# 🔁 Iteration 1
# Max diff: 1.6999999999999997
#
# 🔁 Iteration 2
# Max diff: 1.445
#
# 🔁 Iteration 3
# Max diff: 1.2282500000000003
#
# 🔁 Iteration 4
# Max diff: 1.0440124999999996
#
# 🔁 Iteration 5
# Max diff: 0.887410625000001
#
# 🔁 Iteration 6
# Max diff: 0.75429903125
#
# 🔁 Iteration 7
# Max diff: 0.6411541765624998
#
# 🔁 Iteration 8
# Max diff: 0.544981050078122
#
# 🔁 Iteration 9
# Max diff: 0.46323389256640596
#
# 🔁 Iteration 10
# Max diff: 0.3937488086814454
#
# 🔁 Iteration 11
# Max diff: 0.33468648737922774
#
# 🔁 Iteration 12
# Max diff: 0.28448351427234414
#
# 🔁 Iteration 13
# Max diff: 0.24181098713149252
#
# 🔁 Iteration 14
# Max diff: 0.20553933906176852
#
# 🔁 Iteration 15
# Max diff: 0.1747084382025034
#
# 🔁 Iteration 16
# Max diff: 0.14850217247212785
#
# 🔁 Iteration 17
# Max diff: 0.12622684660130895
#
# 🔁 Iteration 18
# Max diff: 0.10729281961111244
#
# 🔁 Iteration 19
# Max diff: 0.09119889666944558
#
# 🔁 Iteration 20
# Max diff: 0.07751906216902842
#
# 🎯 Extracting Top-N recommendations
# +------------+--------------------+----+
# |          id|                rank|type|
# +------------+--------------------+----+
# |266287973183| 0.08688017185732153|item|
# |266287973540|0.060970151021749554|item|
# |266287973902| 0.06018066165038463|item|
# |266287984874| 0.00971923458665433|item|
# |266287978183|0.006639212978750174|item|
# |266287974088| 0.00608067589057125|item|
# |266287974856|0.005606584578698284|item|
# |266287980867|0.005584617816020647|item|
# |266287984452|0.005568555845915973|item|
# |266287979053|0.004896634207896...|item|
# +------------+--------------------+----+
#
# +------------+--------------------+
# |          id|                rank|
# +------------+--------------------+
# |          10| 0.21256678429658105|
# |266287973183| 0.08688017185732153|
# |266287973540|0.060970151021749554|
# |266287973902| 0.06018066165038463|
# |137438953481|0.040594497143089985|
# |249108103712|0.015098036526325565|
# |128849018946|0.015014398982798974|
# |154618822983|0.014857035802828277|
# |163208757416|0.011325027765175563|
# |266287984874| 0.00971923458665433|
# +------------+--------------------+
# only showing top 10 rows

# %%
#recommendations.printSchema()
#recommendations.show(5)
#recommendations.select("user_id").distinct().count()

# %%
'''from evaluation import evaluate_precision_recall
from pyspark.sql.functions import collect_set
from pyspark.sql.functions import (
    col,
    collect_set,
    collect_list,
    array_intersect,
    size
)
#test_df = spark.read.parquet(PATHS["parquet"] + "/test")

# Ground truth
ground_truth = test_df.groupBy("user_id").agg(
    collect_set("item_id").alias("actual_items")
)

# Keep only users with recommendations
ground_truth = ground_truth.join(
    recommendations.select("user_id").distinct(),
    "user_id"
)

# Evaluate
precision, recall = evaluate_precision_recall(
    recommendations,
    ground_truth,
    k=5
)'''
# Out:
# 'from evaluation import evaluate_precision_recall\nfrom pyspark.sql.functions import collect_set\nfrom pyspark.sql.functions import (\n    col,\n    collect_set,\n    collect_list,\n    array_intersect,\n    size\n)\n#test_df = spark.read.parquet(PATHS["parquet"] + "/test")\n\n# Ground truth\nground_truth = test_df.groupBy("user_id").agg(\n    collect_set("item_id").alias("actual_items")\n)\n\n# Keep only users with recommendations\nground_truth = ground_truth.join(\n    recommendations.select("user_id").distinct(),\n    "user_id"\n)\n\n# Evaluate\nprecision, recall = evaluate_precision_recall(\n    recommendations,\n    ground_truth,\n    k=5\n)'

# %%
'''train_items = train_df.groupBy("user_id").agg(
    collect_set("item_id").alias("seen_items")
)

recommendations = recommendations.join(train_items, "user_id")

recommendations = recommendations.filter(
    ~col("item_id").isin(col("seen_items"))'''
)
